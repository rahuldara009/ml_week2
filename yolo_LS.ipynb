# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics==8.0.20
from IPython import display
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.5/78.2 GB disk)

# %%
# %cd /content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8
# Out:
# /content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8

# %%
# !ls
# Out:
#  data   runs  ' yolo_LS.ipynb'	 yolov8s.pt

# %%
# %cd /content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8

# !yolo task=detect mode=train model=yolov8s.pt data=/content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8/data/data.yaml epochs=25 imgsz=640 batch=16 plots=True
# Out:
# /content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train7/
# Out:
# args.yaml					     results.png	    val_batch0_pred.jpg
# confusion_matrix.png				     train_batch0.jpg	    val_batch1_labels.jpg
# events.out.tfevents.1720899021.c3608da6f779.11600.0  train_batch1425.jpg    val_batch1_pred.jpg
# F1_curve.png					     train_batch1426.jpg    val_batch2_labels.jpg
# P_curve.png					     train_batch1427.jpg    val_batch2_pred.jpg
# PR_curve.png					     train_batch1.jpg	    weights
# R_curve.png					     train_batch2.jpg
# results.csv					     val_batch0_labels.jpg

# %%
# !yolo task=detect mode=val model=/content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8/runs/detect/train7/weights/best.pt data=/content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8/data/data.yaml
# Out:
# 2024-07-13 20:16:43.817703: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-13 20:16:43.817761: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-13 20:16:43.819289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-13 20:16:43.826867: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !yolo task=detect mode=predict model=/content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8/runs/detect/train7/weights/best.pt conf=0.25 source=/content/drive/MyDrive/LS2024/ML/WEEK2/YOLOv8/data/test-20240713T115520Z-001/test/images
# Out:
# 2024-07-13 20:17:31.080398: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-13 20:17:31.080445: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-13 20:17:31.081875: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-13 20:17:31.089157: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
